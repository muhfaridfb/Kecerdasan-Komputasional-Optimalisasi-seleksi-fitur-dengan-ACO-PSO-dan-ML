# %% [markdown]
# # Loading Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Data

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)

# variable information
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
heart_disease
# Out:
# {'data': {'ids': None,
#   'features':      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
#   0     63    1   1       145   233    1        2      150      0      2.3
#   1     67    1   4       160   286    0        2      108      1      1.5
#   2     67    1   4       120   229    0        2      129      1      2.6
#   3     37    1   3       130   250    0        0      187      0      3.5
#   4     41    0   2       130   204    0        2      172      0      1.4
#   ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
#   298   45    1   1       110   264    0        0      132      0      1.2
#   299   68    1   4       144   193    1        0      141      0      3.4
#   300   57    1   4       130   131    0        0      115      1      1.2
#   301   57    0   2       130   236    0        2      174      0      0.0
#   302   38    1   3       138   175    0        0      173      0      0.0
#
#        slope   ca  thal
# ...

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal
# 0        3  0.0   6.0
# 1        2  3.0   3.0
# ...

# %%
y
# Out:
#      num
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# ..   ...
# 298    1
# 299    2
# 300    3
# 301    1
# 302    0
#
# [303 rows x 1 columns]

# %%
y.value_counts()
# Out:
# num
# 0      164
# 1       55
# 2       36
# 3       35
# 4       13
# Name: count, dtype: int64

# %%
data = pd.concat([X,y],axis=1)

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# ...

# %%
df = data.copy()

# %%
df['num'] = df['num'].replace({2: 1, 3: 1, 4: 1})

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    1
# ...

# %% [markdown]
# # Statistical Analysis

# %%
df['num'].value_counts()
# Out:
# num
# 0    164
# 1    139
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %% [markdown]
# # Data Checking

# %%
# Checking null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# ca          4
# thal        2
# cp          0
# trestbps    0
# age         0
# sex         0
# fbs         0
# chol        0
# restecg     0
# thalach     0
# oldpeak     0
# exang       0
# slope       0
# num         0
# dtype: int64

# %%
# Checking duplicate data
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %% [markdown]
# # Data Analysis

# %%
# Heatmap correlation without target feature
corr = df.drop(['num'], axis=1).corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
# Heatmap correlation
corr = df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
# Histogram analysis
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, column in enumerate(df.columns):
    sns.histplot(df[column], kde=True, ax=axes[i])
    axes[i].set_title(f'{column}')

plt.tight_layout()
plt.show()

# %%
# Outlier visualization with boxplot
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, column in enumerate(df.columns):
    sns.boxplot(df[column], ax=axes[i])
    axes[i].set_title(f'{column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
# Copy the data, just in case
df_clean = df.copy()

# %%
# Handle missing values in 'ca'
df_clean['ca'] = df_clean['ca'].fillna(df_clean['ca'].mode()[0])

# %%
# Handle missing values in 'thal'
df_clean['thal'] = df_clean['thal'].fillna(df_clean['thal'].mode()[0])

# %%
df_clean.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# Check target
df_clean['num'].value_counts()
# Out:
# num
# 0    164
# 1    139
# Name: count, dtype: int64

# %% [markdown]
# # Feature Selection

# %%
# Handling outliers by replacing them with the IQR
df_outlier_handled = df_clean.copy()
numeric_columns = df_outlier_handled.select_dtypes(include=[np.number]).columns.tolist()
numeric_columns.remove('num')

for col in numeric_columns:
    Q1 = df_outlier_handled[col].quantile(0.25)
    Q3 = df_outlier_handled[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_outlier_handled[col] = np.where(df_outlier_handled[col] < lower_bound, lower_bound,
                                       np.where(df_outlier_handled[col] > upper_bound, upper_bound, df_outlier_handled[col]))

fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, column in enumerate(df_outlier_handled.columns):
    if column != 'num':
        sns.boxplot(df_outlier_handled[column], ax=axes[i])
        axes[i].set_title(f'{column}')
    else:
        axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Feature selection with chi square
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler

X = df_outlier_handled.drop(['num'], axis=1)
y = df_outlier_handled['num']

scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

chi_scores = chi2(X_scaled, y)
p_values = pd.Series(chi_scores[1], index=X.columns).sort_values()

print("Chi-Square p-values:")
print(p_values)

selected_features = p_values[p_values < 0.05].index.tolist()
X_selected = X[selected_features]

print("\nSelected features based on chi-square (p < 0.05):")
print(selected_features)

df_selected = df_outlier_handled[selected_features + ['num']]
df_selected
# Out:
# Chi-Square p-values:
# thal        2.097045e-11
# exang       6.886243e-10
# ca          2.256238e-08
# oldpeak     4.114184e-05
# slope       9.188519e-04
# cp          1.119985e-03
# sex         6.404399e-03
# restecg     3.761276e-02
# thalach     5.859966e-02
# age         3.158880e-01
# trestbps    4.310847e-01
# chol        6.159039e-01
# fbs                  NaN
# dtype: float64
#
# Selected features based on chi-square (p < 0.05):
# ['thal', 'exang', 'ca', 'oldpeak', 'slope', 'cp', 'sex', 'restecg']
#      thal  exang   ca  oldpeak  slope   cp  sex  restecg  num
# 0     6.0    0.0  0.0      2.3    3.0  1.5  1.0      2.0    0
# 1     3.0    1.0  2.5      1.5    2.0  4.0  1.0      2.0    1
# 2     7.0    1.0  2.0      2.6    2.0  4.0  1.0      2.0    1
# 3     3.0    0.0  0.0      3.5    3.0  3.0  1.0      0.0    0
# 4     3.0    0.0  0.0      1.4    1.0  2.0  0.0      2.0    0
# ..    ...    ...  ...      ...    ...  ...  ...      ...  ...
# ...

# %% [markdown]
# # Modelling

# %%
# Pisahkan fitur dan label
X = df_selected.drop('num', axis=1)
y = df_selected['num']

# Split jadi data train dan test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Cek shape hasil split
print(X_train.shape, X_test.shape)
# Out:
# (212, 8) (91, 8)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import random

def aco_pso_feature_selection(X, y, n_iter=30, n_particles=20):
    features = X.columns.tolist()
    best_score = 0
    best_features = features

    for _ in range(n_iter):
        for _ in range(n_particles):
            # Random pilih jumlah fitur
            n_selected = random.randint(3, len(features))
            selected_features = random.sample(features, n_selected)

            # Model dan cross-validation score
            model = RandomForestClassifier(random_state=42)
            score = cross_val_score(model, X[selected_features], y, cv=5, scoring='accuracy').mean()

            if score > best_score:
                best_score = score
                best_features = selected_features

    return best_features, best_score

# Jalankan seleksi fitur
selected_features, best_cv_score = aco_pso_feature_selection(X_train, y_train)

# Tampilkan hasil
print("Selected Features by ACO-PSO:", selected_features)
print("Best CV Score (Random Forest proxy):", best_cv_score)
# Out:
# Selected Features by ACO-PSO: ['sex', 'exang', 'thal', 'restecg', 'slope', 'ca']
# Best CV Score (Random Forest proxy): 0.8678848283499446

# %%
from sklearn.metrics import accuracy_score, classification_report

# Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train[selected_features], y_train)
y_pred_rf = rf_model.predict(X_test[selected_features])

# Evaluasi
print("\nRandom Forest Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Evaluation:
# Accuracy: 0.7692307692307693
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.79        48
#            1       0.78      0.72      0.75        43
#
#     accuracy                           0.77        91
#    macro avg       0.77      0.77      0.77        91
# weighted avg       0.77      0.77      0.77        91

# %%
from xgboost import XGBClassifier

# XGBoost
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train[selected_features], y_train)
y_pred_xgb = xgb_model.predict(X_test[selected_features])

# Evaluasi
print("\nXGBoost Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Evaluation:
# Accuracy: 0.7362637362637363
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76        48
#            1       0.73      0.70      0.71        43
#
#     accuracy                           0.74        91
#    macro avg       0.74      0.73      0.73        91
# weighted avg       0.74      0.74      0.74        91
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:33:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid Random Forest
param_grid_rf = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7, None],
    'min_samples_split': [2, 4, 6],
    'max_features': ['auto', 'sqrt', 'log2']
}

# GridSearchCV untuk Random Forest
grid_rf = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid=param_grid_rf,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit ke data train
grid_rf.fit(X_train[selected_features], y_train)

# Tampilkan hasil
print("Best Random Forest Params:", grid_rf.best_params_)
print("Best RF CV Score:", grid_rf.best_score_)
# Out:
# Best Random Forest Params: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# Best RF CV Score: 0.8678848283499446
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 180 fits failed out of a total of 540.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
# Parameter grid XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# GridSearchCV untuk XGBoost
grid_xgb = GridSearchCV(
    XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    param_grid=param_grid_xgb,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit ke data train
grid_xgb.fit(X_train[selected_features], y_train)

# Tampilkan hasil
print("Best XGBoost Params:", grid_xgb.best_params_)
print("Best XGBoost CV Score:", grid_xgb.best_score_)
# Out:
# Best XGBoost Params: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Best XGBoost CV Score: 0.8630121816168328
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:39:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.metrics import classification_report, accuracy_score

# Model RF terbaik
best_rf = grid_rf.best_estimator_
y_pred_rf_best = best_rf.predict(X_test[selected_features])

print("\nBest Random Forest Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf_best))
print(classification_report(y_test, y_pred_rf_best))

# Model XGB terbaik
best_xgb = grid_xgb.best_estimator_
y_pred_xgb_best = best_xgb.predict(X_test[selected_features])

print("\nBest XGBoost Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb_best))
print(classification_report(y_test, y_pred_xgb_best))
# Out:
# Best Random Forest Evaluation:
# Accuracy: 0.7802197802197802
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        48
#            1       0.77      0.77      0.77        43
#
#     accuracy                           0.78        91
#    macro avg       0.78      0.78      0.78        91
# weighted avg       0.78      0.78      0.78        91
#
#
# Best XGBoost Evaluation:
# Accuracy: 0.7692307692307693
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        48
#            1       0.75      0.77      0.76        43
#
#     accuracy                           0.77        91
#    macro avg       0.77      0.77      0.77        91
# weighted avg       0.77      0.77      0.77        91

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Model RF terbaik
best_rf = grid_rf.best_estimator_

# Cross-validation di training data
cv_score_rf = cross_val_score(best_rf, X_train[selected_features], y_train, cv=5, scoring='accuracy').mean()
print(f"\nCross-Validation Accuracy (RF): {cv_score_rf:.4f}")

# Prediksi di test data
y_pred_rf_best = best_rf.predict(X_test[selected_features])
print("\nBest Random Forest Evaluation on Test Data:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf_best))
print(classification_report(y_test, y_pred_rf_best))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf_best))


# Model XGB terbaik
best_xgb = grid_xgb.best_estimator_

# Cross-validation di training data
cv_score_xgb = cross_val_score(best_xgb, X_train[selected_features], y_train, cv=5, scoring='accuracy').mean()
print(f"\nCross-Validation Accuracy (XGBoost): {cv_score_xgb:.4f}")

# Prediksi di test data
y_pred_xgb_best = best_xgb.predict(X_test[selected_features])
print("\nBest XGBoost Evaluation on Test Data:")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb_best))
print(classification_report(y_test, y_pred_xgb_best))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb_best))
# Out:
# Cross-Validation Accuracy (RF): 0.8679
#
# Best Random Forest Evaluation on Test Data:
# Accuracy: 0.7802197802197802
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        48
#            1       0.77      0.77      0.77        43
#
#     accuracy                           0.78        91
#    macro avg       0.78      0.78      0.78        91
# weighted avg       0.78      0.78      0.78        91
#
# Confusion Matrix:
#  [[38 10]
#  [10 33]]
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:40:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:40:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Random Forest dengan fitur hasil ACO-PSO
rf_model = RandomForestClassifier(random_state=42)
cv_scores_rf = cross_val_score(rf_model, X[selected_features], y, cv=5, scoring='accuracy')

print("Cross-validation scores (Random Forest):", cv_scores_rf)
print("Mean CV accuracy (Random Forest):", cv_scores_rf.mean())

# XGBoost dengan fitur hasil ACO-PSO
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
cv_scores_xgb = cross_val_score(xgb_model, X[selected_features], y, cv=5, scoring='accuracy')

print("\nCross-validation scores (XGBoost):", cv_scores_xgb)
print("Mean CV accuracy (XGBoost):", cv_scores_xgb.mean())
# Out:
# Cross-validation scores (Random Forest): [0.8852459  0.8852459  0.7704918  0.78333333 0.76666667]
# Mean CV accuracy (Random Forest): 0.8181967213114755
#
# Cross-validation scores (XGBoost): [0.86885246 0.80327869 0.73770492 0.76666667 0.75      ]
# Mean CV accuracy (XGBoost): 0.7853005464480874
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:53:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:53:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:53:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
